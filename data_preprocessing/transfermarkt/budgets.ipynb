# %%
import pandas as pd

col_names = ['Club', 'Age16', 'TMV16'] #TMV - Total Market Value
s16=pd.read_csv('teams/laliga16.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s16['TMV16'] = s16['TMV16'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age15', 'TMV15']
s15=pd.read_csv('teams/laliga15.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s15['TMV15'] = s15['TMV15'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age14', 'TMV14']
s14=pd.read_csv('teams/laliga14.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s14['TMV14'] = s14['TMV14'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age13', 'TMV13']
s13=pd.read_csv('teams/laliga13.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s13['TMV13'] = s13['TMV13'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age12', 'TMV12']
s12=pd.read_csv('teams/laliga12.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s12['TMV12'] = s12['TMV12'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age11', 'TMV11']
s11=pd.read_csv('teams/laliga11.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s11['TMV11'] = s11['TMV11'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age10', 'TMV10']
s10=pd.read_csv('teams/laliga10.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s10['TMV10'] = s10['TMV10'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age09', 'TMV09']
s09=pd.read_csv('teams/laliga09.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s09['TMV09'] = s09['TMV09'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age08', 'TMV08']
s08=pd.read_csv('teams/laliga08.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s08['TMV08'] = s08['TMV08'].str.extract('(\d+)').astype(int)
# Out:
# /home/domino/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:5: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# /home/domino/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:9: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# /home/domino/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:13: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# ...

# %%
laliga = pd.merge(s16, s15, how="outer", on=['Club'])
#laliga = pd.merge(laliga, s14, how="outer", on=['Club'])
#laliga = pd.merge(laliga, s13, how="outer", on=['Club'])
#laliga = pd.merge(laliga, s12, how="outer", on=['Club'])
#laliga = pd.merge(laliga, s11, how="outer", on=['Club'])
#laliga = pd.merge(laliga, s10, how="outer", on=['Club'])
#laliga = pd.merge(laliga, s09, how="outer", on=['Club'])
#laliga = pd.merge(laliga, s08, how="outer", on=['Club'])

laliga
# Out:
#                       Club  Age16  TMV16  Age15  TMV15
# 0              Real Madrid   27.2  764.0   23.8  700.0
# 1             FC Barcelona   27.3  758.0   24.9  618.0
# 2          Atlético Madrid   27.7  501.0   24.4  336.0
# 3               Sevilla FC   27.6  236.0   24.8  186.0
# 4              Valencia CF   26.3  185.0   22.7  254.0
# 5            Villarreal CF   27.9  174.0   24.4  115.0
# 6          Athletic Bilbao   27.7  157.0   26.0  122.0
# 7            Real Sociedad   26.7  114.0   24.6  122.0
# 8            Celta de Vigo   26.3  105.0   23.6   63.0
# 9                Málaga CF   27.2   77.0   26.0   78.0
# 10           UD Las Palmas   27.8   70.0   26.2   29.0
# 11  RCD Espanyol Barcelona   27.8   68.0   24.1   61.0
# 12  Deportivo de La Coruña   28.2   65.0   27.4   51.0
# 13     Real Betis Balompié   27.1   64.0   25.9   72.0
# 14        Deportivo Alavés   26.3   62.0    NaN    NaN
# 15              Granada CF   25.1   57.0   24.9   73.0
# ...

# %%
col_names = ['Club', 'Age16', 'TMV16'] #TMV - Total Market Value
s16=pd.read_csv('teams/PL16.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s16['TMV16'] = s16['TMV16'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age15', 'TMV15']
s15=pd.read_csv('teams/PL15.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s15['TMV15'] = s15['TMV15'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age14', 'TMV14']
s14=pd.read_csv('teams/PL14.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s14['TMV14'] = s14['TMV14'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age13', 'TMV13']
s13=pd.read_csv('teams/PL13.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s13['TMV13'] = s13['TMV13'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age12', 'TMV12']
s12=pd.read_csv('teams/PL12.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s12['TMV12'] = s12['TMV12'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age11', 'TMV11']
s11=pd.read_csv('teams/PL11.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s11['TMV11'] = s11['TMV11'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age10', 'TMV10']
s10=pd.read_csv('teams/PL10.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s10['TMV10'] = s10['TMV10'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age09', 'TMV09']
s09=pd.read_csv('teams/PL09.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s09['TMV09'] = s09['TMV09'].str.extract('(\d+)').astype(int)

col_names = ['Club', 'Age08', 'TMV08']
s08=pd.read_csv('teams/PL08.csv', sep=',', usecols=[2,5,7], header=0, names = col_names, skiprows=1, decimal=',')
s08['TMV08'] = s08['TMV08'].str.extract('(\d+)').astype(int)


pl = pd.merge(s16, s15, how="outer", on=['Club'])
pl = pd.merge(pl, s14, how="outer", on=['Club'])
pl = pd.merge(pl, s13, how="outer", on=['Club'])
pl = pd.merge(pl, s12, how="outer", on=['Club'])
pl = pd.merge(pl, s11, how="outer", on=['Club'])
pl = pd.merge(pl, s10, how="outer", on=['Club'])
pl = pd.merge(pl, s09, how="outer", on=['Club'])
pl = pd.merge(pl, s08, how="outer", on=['Club'])
# Out:
# /home/domino/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   app.launch_new_instance()
# /home/domino/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:7: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# /home/domino/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:11: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# ...

# %%
pl
# Out:
#                        Club  Age16  TMV16  Age15  TMV15  Age14  TMV14  Age13  \
# 0           Manchester City   28.3  525.0   24.4  452.0   25.4  478.0   25.7
# 1                Chelsea FC   26.6  515.0   23.7  579.0   23.9  526.0   23.8
# 2                Arsenal FC   27.2  492.0   23.7  408.0   23.0  404.0   23.8
# 3         Manchester United   27.0  466.0   22.5  374.0   23.9  522.0   24.9
# 4         Tottenham Hotspur   25.3  429.0   22.7  253.0   23.7  298.0   23.4
# 5              Liverpool FC   25.7  372.0   22.5  325.0   23.4  285.0   23.8
# 6                Everton FC   27.0  252.0   24.7  204.0   24.3  177.0   25.9
# 7            Southampton FC   26.2  230.0   24.1  187.0   23.5  150.0   23.9
# 8           West Ham United   27.1  209.0   23.2  185.0   24.8  123.0   25.3
# 9            Leicester City   27.7  205.0   25.9   91.0   25.9   55.0    NaN
# 10           Crystal Palace   28.9  186.0   25.6  121.0   26.0   89.0   26.2
# ...

# %%
frames = [laliga, pl]
teams = pd.concat(frames)
len(teams)
# Out:
# 69

# %%
teams.to_csv('teamsAgeTMV.csv')
